# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge_score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (4.67.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=1dfa00247e1bc89461478c72dbc0e0bac673673bf055ebc8e8fed8b4a97ec5fd
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng', quiet=True)
# Out:
# True

# %%
# ---------- 1. NLTK ----------
for pkg in ['stopwords','punkt','wordnet','averaged_perceptron_tagger','punkt_tab']:
    nltk.download(pkg, quiet=True)

nltk.download('averaged_perceptron_tagger_eng', quiet=True)
# Out:
# True

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import re
import unicodedata
import random
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from tensorflow.keras.layers import TextVectorization
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
for package in ['stopwords', 'punkt', 'wordnet', 'averaged_perceptron_tagger', 'averaged_perceptron_tagger_eng', 'punkt_tab']:
    try:
        nltk.data.find(f'corpora/{package}')
    except:
        nltk.download(package)

# Initialize lemmatizer and stopwords for preprocessing
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
print("NLTK data download complete and lemmatizer initialized.")
# Out:
# NLTK data download complete and lemmatizer initialized.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
def get_wordnet_pos(word):
    """Maps NLTK POS tags to WordNet tags for lemmatization."""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
def normalize(text, label):
    """Normalizes text and formats label."""
    text = unicodedata.normalize("NFKC", text.strip().lower())
    words = nltk.word_tokenize(text)
    words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in words if word not in stop_words]
    text = ' '.join(words)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    text = re.sub(r'\b(the (present )?invention (relates|is directed) to)\b', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\b(\w+)(\s+\1\b)+', r'\1', text)
    formatted_label = f'[start] {label} [end]'
    return text, formatted_label

# %%
def synonym_replacement(words, n=1):
    new_words = list(words)
    random_word_list = list(set([word for word in words if wordnet.synsets(word)]))
    random.shuffle(random_word_list)
    num_replaced = 0
    for random_word in random_word_list:
        synonyms = [lemma.name().replace('_', ' ') for syn in wordnet.synsets(random_word) for lemma in syn.lemmas()]
        synonyms = [s for s in synonyms if s != random_word]
        if synonyms and num_replaced < n:
            synonym = random.choice(synonyms)
            idx = new_words.index(random_word)
            new_words[idx] = synonym
            num_replaced += 1
    return new_words

# %%
def random_word_deletion(words, p=0.1):
    if len(words) < 2: return words
    new_words = [word for word in words if random.uniform(0, 1) > p]
    return new_words if new_words else [random.choice(words)]

# %%
def generate_augmented_samples(text, label, num_samples=3):
    """
    Generates multiple augmented versions of a single text-label pair.
    """
    augmented_samples = [(text, label)]
    words = text.split()
    for _ in range(num_samples - 1):
        # Apply a mix of synonym replacement and random deletion
        if random.uniform(0, 1) < 0.5:
            new_words = synonym_replacement(words, n=max(1, int(len(words) * 0.1))) # Replace ~10% of words
        else:
            new_words = random_word_deletion(words, p=0.1)
        augmented_text = ' '.join(new_words)
        if augmented_text:
            augmented_samples.append((augmented_text, label))
    return augmented_samples

# %%
try:
    df = pd.read_excel('Manual Analysis_input.xlsx', skiprows=4)
    df1 = pd.DataFrame()
    df1['combined'] = df[['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5']].astype(str).agg(' '.join, axis=1)
    df2 = pd.read_excel('actual labels.xlsx', skiprows=3)
    combine = pd.concat([df1.reset_index(drop=True), df2.reset_index(drop=True)], axis=1)

    print(f"combined out put{combine}")

    initial_text_pairs = [normalize(row['combined'], row['Unnamed: 0']) for _, row in combine.iterrows()]
    text_pairs_augmented = [pair for text, label in initial_text_pairs for pair in generate_augmented_samples(text, label, num_samples=5)]
    text_pairs = text_pairs_augmented

    print(f"Original data size: {len(initial_text_pairs)} | Augmented data size: {len(text_pairs)}")
    random.seed(42)
    random.shuffle(text_pairs)
    n_val = int(0.15 * len(text_pairs))
    train_pairs = text_pairs[n_val:]
    test_pairs = text_pairs[:n_val]

    unique_text_tokens = set()
    unique_label_tokens = set()
    max_text_len_observed = 0
    max_label_len_observed = 0
    for text, label in text_pairs:
        text_split = text.split()
        label_split = label.split()
        unique_text_tokens.update(text_split)
        unique_label_tokens.update(label_split)
        max_text_len_observed = max(max_text_len_observed, len(text_split))
        max_label_len_observed = max(max_label_len_observed, len(label_split))

    vocab_text = len(unique_text_tokens) + 2
    vocab_label = len(unique_label_tokens) + 2
    seq_length = max(max_text_len_observed, max_label_len_observed, 25)
    if seq_length < 64: seq_length = 64
    if seq_length > 256: seq_length = 256

    print(f"Max text length observed: {max_text_len_observed} | Max label length observed: {max_label_len_observed}")
    print(f"Calculated vocab_text: {vocab_text} | Calculated vocab_label: {vocab_label}")
    print(f"Selected seq_length for model: {seq_length}")
except Exception as e:
    print(f"Error loading data or applying augmentation: {e}")
    print("Using dummy data and default settings for demonstration.")
    text_pairs = [("hello world", "[start] hello world [end]"), ("how are you doing today", "[start] how are you [end]"), ("this is a test sentence for the transformer model example", "[start] a test example [end]"), ("another short example for understanding code changes", "[start] short code changes [end]"), ("longer sentence to check truncation effects now", "[start] truncation effects [end]"), ("the quick brown fox jumps over the lazy dog often", "[start] fox jumps dog [end]")]
    train_pairs = text_pairs[:4]
    test_pairs = text_pairs[4:]
    vocab_text = 100
    vocab_label = 50
    seq_length = 20
    print(f"Dummy data: Vocab Text Size: {vocab_text}, Vocab Label Size: {vocab_label}, Seq Length: {seq_length}")

# Initialize TextVectorization layers with updated vocab and seq_length
loaded_text_vec = TextVectorization(max_tokens=20000, split='whitespace', output_mode='int', output_sequence_length=seq_length, standardize='lower_and_strip_punctuation', ngrams=None)
loaded_label_vec = TextVectorization(max_tokens=20000, split='whitespace', output_mode='int', output_sequence_length=seq_length, standardize=None, ngrams=None)
loaded_text_vec.adapt([pair[0] for pair in train_pairs])
loaded_label_vec.adapt([pair[1] for pair in train_pairs])
print("\nTextVectorization layers adapted.")
# Out:
# combined out put                                             combined  \
# 0   METHOD AND DEVICE FOR LOADING A FIBRE-BASED CO...
# 1   FIBER-BASED CONTAINER The invention relates to...
# 2   CONTAINER The present invention relates to a m...
# 3   A METHOD FOR PROVIDING A NON-UNIFORM BARRIER C...
# 4   METHOD FOR FORMING A CONTAINER WITH A PLASTIC ...
# ..                                                ...
# 76  LIQUID CONTAINER AND ITS MANUFACTURING METHOD ...
# 77  Paper container having a reinforced neck A con...
# 78  Paperboard bottle A bottle type container is f...
# 79  INTEGRAL PULP-MOLDED BOTTLE, MOLD FOR MOLDING ...
# 80  Paper-plastic integrated bottle and forming di...
#
#                                            Unnamed: 0
# 0   Equipment for manufacturing and Method of Manu...
# 1   Material of product/ barrier and Method of Man...
# 2   Method of Manufacturing and Structure of the p...
# 3                            Method of Manufacturing
# 4   Method of Manufacturing and Structure of the p...
# ..                                                ...
# 76  Structure of the product and Method of Manufac...
# 77  Structure of the product, Method of Manufactur...
# 78  Structure of the product and Material of produ...
# 79  Equipment for manufacturing and Method of Manu...
# 80  Equipment for manufacturing and Method of Manu...
#
# [81 rows x 2 columns]
# Original data size: 81 | Augmented data size: 405
# Max text length observed: 3487 | Max label length observed: 17
# Calculated vocab_text: 5249 | Calculated vocab_label: 23
# Selected seq_length for model: 256
#
# TextVectorization layers adapted.

# %%
train_pairs
# Out:
# [('hollow container problem manufacture pulp hollow container strength superior productivity superior outer appearance solution 10 make pulp form opening 11 body 12 bottom 13 seam form body shape transverse face body 12 large transverse face opening 11 outer face inner face form smoothly preferably density hollow 10 0420 gm2 moisture permeability 100 gm224 hr less jp2000025733a 1 opening form pulp compose body bottom body seam shape make crosssectional shape opening outer surface inner surface make smooth supply pressure 5mp inside hollow core supply pressurize fluid expand core hollow container characterize rukoto obtain heat dry pressure inner mold 2 hollow container accord 1 wherein container cylindrical shape diameter body large diameter opening 3 hollow container accord claim 1 wherein body bottom 4 hollow accord claim 1 wherein density 04 20 g cm 3 5 hollow container claim 1 wherein water vapor transmission 100 g 2 24 hr less 6 hollow container accord claim 1 wherein plastic layer form outer surface surface 7 hollow container accord claim 1 wherein part opening form plastic 8 pusher accord claim 1 wherein say core expand due pressure surface mold form outer surface hollow container hollow container accord one claim 1 7 wherein vessel 9 center line average roughness ra m less maximum ry 500 m less 9 hollow accord one item 1 8 1 opening form mainly pulp compose body bottom body seam crosssectional shape body large crosssectional shape outer surface inner surface make smoothand supply pressure 001 inside hollow coreby pressurize fluid expand corehollow container rukotoobtained heat dry pressure inner surface mold 9 thecenter line average roughness ra 50 m lessand maximum height 500 m lessitem 9 hollow accord one item 1',
#   '[start] Structure of the product [end]'),
#  ('method apparatus coating container provide method coat container particular beverage container worthy stand for have liquid wherein container coat master body shoulder neighborhood infrastructure region mouth region wherein coat internal fence andor out wall container siliconcontaining coat material bring about flowable harbinger apply inner wall andor outer wall container coat container bring in fiberbased material ane method coat container particular beverage container suitable intend receive liquid wherein container coat main body shoulder region base region mouth region wherein coat inner wall andor outer wall container siliconcontaining coat material produce flowable precursor apply to the lowest degree one inner wall outer wall container wherein container coat container make fiberbased material II method accord call 1 wherein container order coat chamber coat 3 method accord claim 1 wherein siliconcontaining coat material siox quaternity method accord claim 1 wherein coat inner wall container flowable precursor vaporise together gaseous metier oxygencontaining gasoline infix midland container Phoebe method accord claim 1 wherein flowable precursor apply thermic action outer wall container coat outer wall container sixer method accord claim 1 wherein flowable precursor select aggroup precursor admit hmdso hmdsn teos sicontaining colonial the like heptad method accord claim 1 wherein coat inner wall outer wall container carry at the same time least clock time eighter from Decatur method accord claim 1 wherein least main body shoulder region base region container produce fiberbased material 9 method accord claim 1 wherein least mouth region container well produce credit card material select group favorite pp atomic number 15 pe x method accord claim 1 wherein container law of closure wherein closure produce plastic material select group consist pet pp p pe metal 11 apparatus coat container particular beverage container suitable intend receive liquid wherein container coat main body shoulder region base region mouth region apparatus multitude coat place wherein container carry device coat station wherein privileged coat station siliconcontaining coat material apply inner wall outer wall container wherein container coat container make fiberbased material 12 container receive liquid particular beverage wherein container successively on longitudinal focal point mouth region shoulder region main body base region wherein least main body base region container produce fiberbased material qualify container coat make siliconcontaining coat material inner wall outer wall XIII container accord claim 1 wherein fiberbased material select group material include mush material papier mch cellulose newspaper pulp xiv container accord claim 1 wherein least main body shoulder region base region container produce fiberbased material xv method accord claim 10 wherein container closure wherein closure produce atomic number 13 1 method coat container particular beverage container suitable intend receive liquid wherein container coat main body shoulder region base region mouth region wherein coat inner wall andor outer wall container siliconcontaining coat material produce flowable precursor apply least one inner wall outer wall container wherein container coat container make fiberbased material 11 apparatus coat container particular beverage container suitable intend receive liquid wherein container coat main body shoulder region base region mouth region apparatus plurality coat station wherein container transport device coat station wherein inside coat station siliconcontaining coat material apply inner wall outer wall container wherein container coat container make fiberbased material 12 container receive liquid particular beverage wherein container successively along longitudinal direction mouth region shoulder region main body base region wherein least main body base region container produce fiberbased material characterise container coat m ...
#   '[start] Method of Manufacturing, Structure of the product, Equipment for manufacturing and Material of product/ barrier [end]'),
#  ('particulate material container hold particulate material provide container may form mold pulp container include mold pulp shape thread form integrally container may aid provide closure device container may optionally fitment andor liner may free fitment liner container optionally inner load member container may stackable 1 container hold particulate material comprise mold pulp shell body comprise 1 hinge pulp form enclose body 2 multiple pulp shell include first pulp shell second pulp shell join together form enclose wherein mold pulp shell configure contain particulate material enclose body orifice mold shell body configure permit passage particulate material orifice mold pulp shell body wherein 1 portion first side hinge pulp shell form overlap second side hinge pulp shell 2 portion first pulp shell form overlap second pulp shell provide substantially flat surface overlap 2 container 1 wherein overlap locate base container side wall container 3 container claim 1 comprise support attach mold pulp shell body neck mold pulp shell body surround orifice thereby provide support pulp shell 4 container claim 3 wherein support ring form one pulp fiber cardboard plastic metal 5 container claim 1 first pulp shell first flange protrude surface first pulp shell second pulp shell comprises second flange protrude surface second pulp shell wherein flange second attach one another thereby form secure connection 6 container claim 1 comprise internal liner orifice coextensive orifice container liner separate mold pulp shell body direct contact particulate material particulate material contain therein 7 container claim 1 wherein overlap connect aid adhesive select one follow hot melt adhesive latex contact adhesive pressure cure adhesive 8 container claim 7 wherein adhesive permit overlap form secure connection form mold pulp shell body contains material 9 container claim 1 comprise pulp pan contain within mold pulp shell body 10 container claim 1 wherein mold pulp body comprises shape feature configure easy grip container 11 container claim 1 wherein pulp shell body configure receive reclosable 12 container claim 1 wherein multiple pulp shell include top pulp shell surround orifice bottom pulp shell oppose top pulp 13 container claim 1 wherein multiple pulp shell include front pulp shell back pulp shell wherein orifice combination front pulp shell back pulp shell 14 container claim 1 comprise least one inner load part configure align vertically another inner load bearing part another container vertically stack 15 container claim 12 wherein top pulp shell configure slidably overlap bottom pulp shell translate relative bottom pulp top pulp shell affixed bottom pulp shell top pulp shell coincident particulate contain within pulp body 16 container claim 12 wherein top pulp shell configure receive bottom overlie container 17 container 1 wherein bottom surface mold pulp shell body include recess upper portion underlie container wherein least load container underlie container bypass upper protrude portion 18 claim 11 wherein lid select one flip lid snap lid directional funnel thread cap press fit lid container claim 1 mold pulp shell body waterproof finish 20 system hold container comprise plurality container claim 1 slip sheet comprise plurality hole locate top plurality container place 21 hold material comprise mold pulp shell configure contain material therein mold thread integrally form mold pulp shell thread closure configure mate mold pulp thread 1 container hold particulate material comprise mold pulp shell body comprise 1 hinge shell foldable form enclose body 2 multiple pulp shell include first pulp shell second pulp shell join together form enclose body wherein mold pulp shell body configure contain particulate material within enclose body andan orifice mold pulp shell body configure permit passage particulate material orifice mold pulp shell body wherein least portion first hinge pulp shell form overlap side hinge pulp shell 2 least por ...
#   '[start] Material of product/ barrier Material of product/ barrier and Method of Manufacturing [end]'),
#  ('composite container provide composite container give sense high quality easily allow separation paper plastic time disposalsolution composite container comprises papermade outer container inner container laminate include film container compose first member comprise cylindrical first trunk part bottom part closing one second member compose pulp mold comprise trunk part join part join opening trunk part opening end part join side first part taper toward opening end part first neck part opening first member join trunk join part second member inner container comprises body device body second trunk part taper second shoulder part second neck part container outer container outer container disassemble first member second memberselected draw figure 1 composite container comprise outer container make paper inner container provide laminate contain plastic wherein inner container outer container outer container first member consist cylindrical first body bottom one opening close body joint part join opening first body part one side opening end part side second body part connect body joint part taper toward opening end part second member base material make pulp mold first neck connect first shoulder end opening first member join trunk joint second container comprises pouch body pour tool pouch body heatbonded part peripheral edge tool bond part pouch body include second body portion second shoulder portion connect body portion pour tool second shoulder portion second shoulder portion extend toward pour tool neck inner container cover outer container composite outer container dismantle first member second 2 trunk joint portion second member outward first shoulder portion outer circumference trunk joint portion small inner first trunk first member 2 composite container accord claim 1 say body joint fit inside say first body 1 container comprise outer container make paper container laminate contain film wherein inner cover outer container outer container first member consist cylindrical first body bottom opening close body joint part join opening first part one side part side body part connect body joint part taper toward opening end part second member base material pulp first connect shoulder open end opening first member join trunk joint second inner container comprises pouch body pour tool pouch body heatbonded peripheral edge pour tool bond heatbonded part pouch body include second body portion second shoulder portion connect second body portion taper toward pour tool second shoulder portion continue second shoulder portion extend pour neck inner container cover outer composite container wherein outer container dismantle first member second 2 joint portion second extends outward first shoulder portion outer circumference trunk joint portion inner circumference first trunk portion first member',
#   '[start] Structure of the product  [end]'),
#  ('modular container improve performance container include pulpformed shell configure contain material therein pulpformed shell comprise opening material may pas collar connect shell one feature configure engage least portion pulpformed shell component rotatably couple collar component operable move material within pulpformed shell along axis pulpformed 1 container pulpformed shell configure contain material therein pulpformed shell comprise opening material may pas collar connect pulpformed shell one feature configure engage portion pulpformed shell component rotatably couple collar wherein rotation component operable move material within pulpformed shell along axis pulpformed shell 2 container claim wherein pulpformed shell form material collar form second material different first material container claim 1 wherein shell form first material collar form second material first material second material 4 container claim 1 wherein collar include inner space end pulpformed shell receivable within inner space 5 container claim 1 wherein one feature configure engage least portion pulpformed shell arrange within inner space 6 container claim 1 wherein component movable relative collar along axis pulpformed shell 7 container claim 1 width component great width collar 8 container claim 1 wherein component receive within interior collar 9 claim 8 wherein component thread post 10 container claim 8 comprise least one cup liner movably mount within interior pulpformed shell one cup liner operably couple component 11 claim wherein least one liner movable along axis interior pulp form shell response rotation component 12 container claim 10 wherein one cup liner component comprises thread post configure cooperate opening least one cup liner relative shell 42 13 container pulpformed shell configure contain material therein pulpformed shell comprise opening material may pas cap connect interior pulpformed shell cap one feature configure engage least portion pulpformed shell wherein rotatable relative pulpformed shell movable along axis pulpformed shell 14 claim 13 wherein pulpformed shell first material cap form material different first material 15 container claim 13 wherein pulpformed shell form first material cap second material first material second material 16 container claim 13 container plurality surface feature one feature collar engage within plurality surface feature 17 claim 16 wherein plurality surface feature include plurality thread 18 container 17 wherein collar comprises cup twister part connect cup 19 container claim 18 wherein twister part include plurality protr
#  ('container nowadays invention refer method acting form container method incorporate allow for containershaped fibrebased shell ace disconfirming mould ii match shape shell wherein shell nonflat shape rear end triad elimination yap 4 5 first gear dower bottom shell blow mold preform sextet inwardly shell plastic blood form inner surface shell outer surface shell press surround surface negative mold container likewise present ep3375592a1 1 method form container method make up provide containershaped fibrebased shell 1 negative mold 2 match shape shell wherein shell nonflat shape bottom 3 b blow mold preform 6 inside shell plastic line form inner surface shell outer surface shell press wall surface negative mold wherein bottom convex outer rim concave centre portion characterise evacuation hole 5 low portion bottom shell 2 method take 1 wherein blow mold tread b extend blow mold injectant stretch blow mold 3 method claim 1 2 wherein bottom comprises evacuation hole 4 centre portion bottom shell 4 method unmatched claim 1 3 wherein bottom comprises one evacuation hole 5 rim bottom 5 method one claim 1 4 wherein evacuation hole 4 centre portion bottom shell big tropical sprue VII preform 6 method one claim 1 5 wherein shell bottleshaped 7 method one claim 1 6 wherein shell form hold pressurise adept pressurize liquid particularly carbonate liquid octet method one claim 1 7 wherein step predate step form shell fibrebased pulp shellforming mold shellforming mold dissimilar negative mold consumption step b 9 method one claim 1 8 wherein negative mold split up mold two match one-half tenner container comprise fibrebased shell 1 plastic line inner surface shell wherein plastic line form blow mold preform inside shell wherein bottom convex outer rim concave centre portion characterize evacuation hole 5 low portion nonflat shape bottom shell eleven container claim 10 wherein fibrebased shell 1 evacuation hole 4 centre portion bottom shell twelve container claim 10 11 wherein bottom comprises one evacuation hole 5 rim bottom long dozen container one claim 10 12 wherein evacuation hole 4 centre portion bottom shell large sprue 7 preform XIV container one claim 10 13 wherein shell bottleshaped fifteen container one claim 10 14 wherein shell form contain pressurize good pressurize liquid particularly carbonate liquid 1 method form container method comprise provide containershaped fibrebased shell 1 negative mold 2 match shape shell wherein shell nonflat shape bottom 3 andb blow mold preform 6 inside shell plastic line form inner surface shell outer surface shell press wall surface negative mold wherein bottom convex outer rim concave centre portion characterize byhaving evacuation hole 5 low portion bottom shell 10 container comprise fibrebased shell 1 anda plastic line inner surface shell wherein plastic line form blow mold preform inside shell wherein bottom convex outer rim concave centre portion characterize byhaving evacuation hole 5 low portion nonflat shape bottom shell',
#   '[start] Method of Manufacturing and Structure of the product [end]'),
#  ('complex container render composite container give good sense high quality easily take into account separation newspaper credit card fourth dimension disposalsolution composite container comprises prohibited container base cloth indite mush forge inner container laminate admit plastic film outer container include first trunk start opening end part first shoulder part tie first trunk part prolong toward opening end part first cervix part connect first shoulder part opening end part inner container include second gear trunk part second shoulder part connect second trunk part extend toward opening end part second neck part connect second shoulder part extend toward opening end part composite container inner container comprehend outer container outer container disassemble along intersect section disunite opening end part first neck part first shoulder part first trunk partselected draw image unity equip outer container substratum make pulp mold inner container laminate contain plastic film outer container include first trunk open end first shoulder connect first trunk extend toward open end continuous connection first shoulder open end first neck provide inner container include second body second shoulder connect second body extend toward opening end second shoulder continue second shoulder extend toward opening end II neck composite container inner container cover outer container composite container wherein outer container dismantle along cross section divide open end first neck first shoulder first body 2 counsel outer container divide open end luck first neck portion first shoulder portion first body portion take upright direction horizontal direction first body portion cross vertical direction 2 composite container accord call 1 wherein crosssectional shape egg-shaped outer container dismantle along John Major axis of rotation oval 3 composite container accord claim 1 wherein base material outer container contains thermoplastic resin resin 1 equip outer container substrate make pulp mold inner container laminate contain plastic film outer container include first trunk open end first shoulder connect first trunk extend toward open end continuous connection first shoulder open end first neck provide inner container include second body second shoulder connect second body extend toward opening end second shoulder continue second shoulder extend toward opening end 2 neck composite container inner container cover outer container composite container wherein outer container dismantle along cross section divide open end first neck first shoulder first body',


# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def pos_enc_matrix(L, d, n=10000):
    assert d % 2 == 0
    d2 = d // 2
    P = np.zeros((L, d))
    k = np.arange(L).reshape(-1, 1)
    i = np.arange(d2).reshape(1, -1)
    denom = np.power(n, -i / d2)
    args = k * denom
    P[:, ::2] = np.sin(args)
    P[:, 1::2] = np.cos(args)
    return P

# %%
class PositionalEmbedding(tf.keras.layers.Layer):
    def __init__(self, seq_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.seq_length = seq_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.token_embeddings = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embed_dim, mask_zero=True, dtype='float32')
        matrix = pos_enc_matrix(seq_length, embed_dim)
        self.positional_embedding = tf.constant(matrix, dtype=tf.float32)

    def call(self, inputs):
        embedded_tokens = self.token_embeddings(inputs)
        embedded_tokens = tf.cast(embedded_tokens, tf.float32)
        sliced_positional_embedding = self.positional_embedding[:tf.shape(embedded_tokens)[1], :]
        return embedded_tokens + sliced_positional_embedding

    def compute_mask(self, inputs, mask=None):
        return self.token_embeddings.compute_mask(inputs, mask=mask)

    def get_config(self):
        config = super().get_config()
        config.update({'seq_length': self.seq_length, 'vocab_size': self.vocab_size, 'embed_dim': self.embed_dim})
        return config

# %%
def scaled_dot_product_attention_manual(query, key, value, dk_val, mask=None):
    matmul_qk = tf.matmul(query, key, transpose_b=True)
    dk = tf.cast(dk_val, tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)
    if mask is not None:
        scaled_attention_logits = tf.where(mask, scaled_attention_logits, -1e9)
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)
    output = tf.matmul(attention_weights, value)
    return output, attention_weights

# %%
class MultiHeadSelfAttention(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads
        if self.head_dim * num_heads != embed_dim:
            raise ValueError("embedding_dim should be divisible by num_heads")
        self.wq = tf.keras.layers.Dense(embed_dim, use_bias=False)
        self.wk = tf.keras.layers.Dense(embed_dim, use_bias=False)
        self.wv = tf.keras.layers.Dense(embed_dim, use_bias=False)
        self.dense = tf.keras.layers.Dense(embed_dim)
        self.supports_masking = True
    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.head_dim))
        return tf.transpose(x, perm=[0, 2, 1, 3])
    def call(self, inputs, mask=None):
        batch_size = tf.shape(inputs)[0]
        seq_len = tf.shape(inputs)[1]
        padding_mask = tf.cast(tf.expand_dims(tf.expand_dims(inputs._keras_mask, 1), 1), dtype=tf.bool) if hasattr(inputs, '_keras_mask') and inputs._keras_mask is not None else None
        q, k, v = self.wq(inputs), self.wk(inputs), self.wv(inputs)
        q, k, v = self.split_heads(q, batch_size), self.split_heads(k, batch_size), self.split_heads(v, batch_size)
        combined_attention_mask = None
        if padding_mask is not None and mask is True:
            causal_mask_tensor = tf.linalg.band_part(tf.ones((seq_len, seq_len), dtype=tf.bool), -1, 0)
            causal_mask_tensor = tf.expand_dims(tf.expand_dims(causal_mask_tensor, 0), 0)
            combined_attention_mask = tf.logical_and(padding_mask, causal_mask_tensor)
        elif padding_mask is not None:
            combined_attention_mask = padding_mask
        elif mask is True:
            causal_mask_tensor = tf.linalg.band_part(tf.ones((seq_len, seq_len), dtype=tf.bool), -1, 0)
            combined_attention_mask = tf.expand_dims(tf.expand_dims(causal_mask_tensor, 0), 0)
        scaled_attention, _ = scaled_dot_product_attention_manual(q, k, v, self.head_dim, combined_attention_mask)
        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.embed_dim))
        output = self.dense(concat_attention)
        if hasattr(inputs, '_keras_mask') and inputs._keras_mask is not None:
            output._keras_mask = inputs._keras_mask
        return output
    def get_config(self):
        config = super().get_config()
        config.update({'embed_dim': self.embed_dim, 'num_heads': self.num_heads})
        return config

# %%
class MultiHeadCrossAttention(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads
        if self.head_dim * num_heads != embed_dim:
            raise ValueError("embedding_dim should be divisible by num_heads")
        self.wq = tf.keras.layers.Dense(embed_dim, use_bias=False)
        self.wk = tf.keras.layers.Dense(embed_dim, use_bias=False)
        self.wv = tf.keras.layers.Dense(embed_dim, use_bias=False)
        self.dense = tf.keras.layers.Dense(embed_dim)
        self.supports_masking = True
    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.head_dim))
        return tf.transpose(x, perm=[0, 2, 1, 3])
    def call(self, inputs):
        query_input, context_input = inputs
        batch_size = tf.shape(query_input)[0]
        query_padding_mask = tf.cast(tf.expand_dims(tf.expand_dims(query_input._keras_mask, 1), -1), dtype=tf.bool) if hasattr(query_input, '_keras_mask') and query_input._keras_mask is not None else None
        context_padding_mask = tf.cast(tf.expand_dims(tf.expand_dims(context_input._keras_mask, 1), 1), dtype=tf.bool) if hasattr(context_input, '_keras_mask') and context_input._keras_mask is not None else None
        attention_mask_for_sdp = tf.logical_and(query_padding_mask, context_padding_mask) if query_padding_mask is not None and context_padding_mask is not None else query_padding_mask if query_padding_mask is not None else context_padding_mask if context_padding_mask is not None else None
        q, k, v = self.wq(query_input), self.wk(context_input), self.wv(context_input)
        q, k, v = self.split_heads(q, batch_size), self.split_heads(k, batch_size), self.split_heads(v, batch_size)
        scaled_attention, _ = scaled_dot_product_attention_manual(q, k, v, self.head_dim, attention_mask_for_sdp)
        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.embed_dim))
        output = self.dense(concat_attention)
        if hasattr(query_input, '_keras_mask') and query_input._keras_mask is not None:
            output._keras_mask = query_input._keras_mask
        return output
    def get_config(self):
        config = super().get_config()
        config.update({'embed_dim': self.embed_dim, 'num_heads': self.num_heads})
        return config

# %%
class FeedForward(tf.keras.layers.Layer):
    def __init__(self, model_dim, ff_dim, dropout=0.2, **kwargs):
        super().__init__(**kwargs)
        self.model_dim = model_dim
        self.ff_dim = ff_dim
        self.dropout_rate = dropout
        self.dense1 = tf.keras.layers.Dense(ff_dim, activation='relu')
        self.dense2 = tf.keras.layers.Dense(model_dim)
        self.drop = tf.keras.layers.Dropout(dropout)
        self.norm = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.add = tf.keras.layers.Add()
        self.supports_masking = True
    def call(self, inputs):
        input_mask = inputs._keras_mask if hasattr(inputs, '_keras_mask') else None
        ffout = self.drop(self.dense2(self.dense1(inputs)))
        output = self.norm(self.add([inputs, ffout]))
        if input_mask is not None:
            output._keras_mask = input_mask
        return output
    def get_config(self):
        config = super().get_config()
        config.update({'model_dim': self.model_dim, 'ff_dim': self.ff_dim, 'dropout_rate': self.dropout_rate})
        return config

# %%
class EncoderBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.rate = rate
        self.att = MultiHeadSelfAttention(embed_dim=embed_dim, num_heads=num_heads)
        self.ffn = FeedForward(model_dim=embed_dim, ff_dim=ff_dim, dropout=rate)
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.add = tf.keras.layers.Add()
        self.supports_masking = True
    def call(self, inputs, training=False):
        attn_output = self.att(inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(self.add([inputs, attn_output]))
        ffn_output = self.ffn(out1)
        return self.layernorm2(self.add([out1, ffn_output]))
    def get_config(self):
        config = super().get_config()
        config.update({'embed_dim': self.embed_dim, 'num_heads': self.num_heads, 'ff_dim': self.ff_dim, 'rate': self.rate})
        return config

# %%
class DecoderBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.rate = rate
        self.self_att = MultiHeadSelfAttention(embed_dim=embed_dim, num_heads=num_heads)
        self.cross_att = MultiHeadCrossAttention(embed_dim=embed_dim, num_heads=num_heads)
        self.ffn = FeedForward(model_dim=embed_dim, ff_dim=ff_dim, dropout=rate)
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.add = tf.keras.layers.Add()
        self.supports_masking = True
    def call(self, x, enc_output, training=False):
        attn1 = self.self_att(x, mask=True)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(self.add([x, attn1]))
        attn2 = self.cross_att([out1, enc_output])
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(self.add([out1, attn2]))
        ffn_output = self.ffn(out2)
        return self.layernorm3(self.add([out2, ffn_output]))
    def get_config(self):
        config = super().get_config()
        config.update({'embed_dim': self.embed_dim, 'num_heads': self.num_heads, 'ff_dim': self.ff_dim, 'rate': self.rate})
        return config

# %%
def transformer(num_layers, num_heads, text_seq_length, label_seq_length, embed_dim, ff_dim, vocab_text, vocab_label, dropout=0.2, name='transformer'):
    input_enc = tf.keras.layers.Input(shape=(text_seq_length,), dtype='int64', name='encode_inp')
    # The decoder input layer's shape is now set to the correct length
    input_dec = tf.keras.layers.Input(shape=(label_seq_length,), dtype='int64', name='decode_inp')

    x_enc_emb = PositionalEmbedding(text_seq_length, vocab_text, embed_dim, name='embed_encoders')(input_enc)
    x_dec_emb = PositionalEmbedding(label_seq_length, vocab_label, embed_dim, name='embed_decoders')(input_dec)

    x_enc_emb = tf.keras.layers.Dropout(dropout)(x_enc_emb)
    x_dec_emb = tf.keras.layers.Dropout(dropout)(x_dec_emb)

    encoder_output = x_enc_emb
    for i in range(num_layers):
        encoder_output = EncoderBlock(embed_dim=embed_dim, ff_dim=ff_dim, rate=dropout, num_heads=num_heads, name=f"encoder_block_{i}")(encoder_output)

    decoder_output = x_dec_emb
    for i in range(num_layers):
        decoder_output = DecoderBlock(embed_dim=embed_dim, ff_dim=ff_dim, rate=dropout, num_heads=num_heads, name=f"decoder_block_{i}")(x=decoder_output, enc_output=encoder_output)

    output_logits = tf.keras.layers.Dense(vocab_label, name='linear')(decoder_output)
    if hasattr(output_logits, '_keras_mask'):
        del output_logits._keras_mask
    model = tf.keras.Model(inputs=[input_enc, input_dec], outputs=output_logits, name=name)
    return model

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super().__init__()
        self.d_model = tf.cast(d_model, tf.float32)
        self.warmup_steps = warmup_steps
    def __call__(self, step):
        arg1 = tf.math.rsqrt(tf.cast(step, tf.float32))
        arg2 = tf.cast(step, tf.float32) * (self.warmup_steps**-1.5)
        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)
    def get_config(self):
        config = {'d_model': self.d_model.numpy(), 'warmup_steps': self.warmup_steps}
        return config

# %%
def masked_loss(label, pred):
    pred_sliced = pred[:, :tf.shape(label)[1], :]
    mask = label != 0
    loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
    loss = loss_object(label, pred_sliced)
    mask_float = tf.cast(mask, dtype=loss.dtype)
    loss *= mask_float
    sum_loss = tf.reduce_sum(loss)
    sum_mask = tf.reduce_sum(mask_float)
    final_loss = tf.cond(tf.equal(sum_mask, 0), lambda: tf.constant(0.0, dtype=loss.dtype), lambda: sum_loss / tf.maximum(sum_mask, tf.keras.backend.epsilon()))
    return final_loss

# %%
def mask_accuracy(label, pred):
    pred_token_ids = tf.argmax(pred, axis=2)
    label_casted = tf.cast(label, pred_token_ids.dtype)
    pred_token_ids = pred_token_ids[:, :tf.shape(label_casted)[1]]
    match = tf.math.equal(label_casted, pred_token_ids)
    mask = label_casted != 0
    match = tf.math.logical_and(match, mask)
    match = tf.cast(match, dtype=tf.float32)
    mask = tf.cast(mask, dtype=tf.float32)
    safe_mask_sum = tf.maximum(tf.reduce_sum(mask), tf.keras.backend.epsilon())
    return tf.reduce_sum(match) / safe_mask_sum

# %%
def format_dataset(text, label, is_predict=False):
    text_vec = loaded_text_vec(text)
    label_vec = loaded_label_vec(label)
    decode_inp = label_vec[:, :-1]
    target = label_vec[:, 1:]
    if is_predict:
        source = {'encode_inp': text_vec, 'decode_inp': tf.zeros_like(decode_inp, dtype=tf.int64)}
    else:
        source = {'encode_inp': text_vec, 'decode_inp': decode_inp}
    return source, target

# %%
def make_dataset(pairs, batch_size=64, is_predict=False):
    text_data, label_data = zip(*pairs)
    dataset = tf.data.Dataset.from_tensor_slices((list(text_data), list(label_data)))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(lambda x, y: format_dataset(x, y, is_predict=is_predict), num_parallel_calls=tf.data.AUTOTUNE)
    if not is_predict:
        dataset = dataset.shuffle(2048).prefetch(tf.data.AUTOTUNE).cache()
    else:
        dataset = dataset.cache().prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
embed_dim = 512
ff_dim = 2048
num_layers = 4
num_heads = 8
dropout = 0.2

# Make sure the `seq_length` and `vocab` variables are correctly defined from the data loading step.
train_ds = make_dataset(train_pairs)
test_ds = make_dataset(test_pairs)

# %%
print(train_ds)
# Out:
# <CacheDataset element_spec=({'encode_inp': TensorSpec(shape=(None, 256), dtype=tf.int64, name=None), 'decode_inp': TensorSpec(shape=(None, 255), dtype=tf.int64, name=None)}, TensorSpec(shape=(None, 255), dtype=tf.int64, name=None))>

# %%
print("\n--- Building Full Transformer Model ---")
# Increased num_layers to 4 and reduced dropout to 0.2
# Assuming seq_length is 256
transformer_model = transformer(
    num_layers=num_layers,
    num_heads=num_heads,
    text_seq_length=seq_length,
    label_seq_length=seq_length - 1,
    embed_dim=embed_dim,
    ff_dim=ff_dim,
    vocab_text=vocab_text,
    vocab_label=vocab_label,
    dropout=dropout,
    name='my_transformer_model'
)
# Compiling the model
# Using a fixed AdamW learning rate for faster convergence on a small dataset
optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-4, weight_decay=1e-4)
# Alternative using the custom schedule:
# learning_rate = CustomSchedule(d_model=embed_dim)
# optimizer = tf.keras.optimizers.AdamW(learning_rate=learning_rate, weight_decay=1e-4)
transformer_model.compile(loss=masked_loss, optimizer=optimizer, metrics=[mask_accuracy])

# Increased EarlyStopping patience to 10
callbacks = [EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True), ModelCheckpoint('best_model.h5', save_best_only=True)]

print(f"Starting training for 200 epochs (with EarlyStopping up to {callbacks[0].patience} epochs patience).")
try:
    history = transformer_model.fit(train_ds, validation_data=test_ds, epochs=200, callbacks=callbacks)
    print("\nTraining complete!")

    # Evaluation and plotting code
    print("\n--- Evaluating Model ---")
    loss, accuracy = transformer_model.evaluate(test_ds)
    print(f"Test Loss: {loss:.4f}")
    print(f"Test Accuracy: {accuracy:.4f}")

    # Plot training and validation loss
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig('loss_plot.png')

    # Plot training and validation accuracy
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['mask_accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_mask_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.savefig('accuracy_plot.png')

    print("\n--- Predicting and Comparing with Test Data ---")
    label_vocab = loaded_label_vec.get_vocabulary()
    index_to_label = {index: token for index, token in enumerate(label_vocab)}
    text_vocab = loaded_text_vec.get_vocabulary()
    index_to_text = {index: token for index, token in enumerate(text_vocab)}

    def tokens_to_text(token_ids, vocab_map):
        tokens = [vocab_map.get(token_id, '[UNK]') for token_id in token_ids if token_id != 0]
        filtered_tokens = [token for token in tokens if token not in ['[start]', '[end]']]
        return ' '.join(filtered_tokens)

    # Placeholder for ROUGE score calculation
    def calculate_rouge_scores(references, candidates):
        """
        Placeholder function for calculating ROUGE scores.
        You would replace this with actual logic using a library like rouge-score.
        Example:
        from rouge_score import rouge_scorer
        scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
        scores = [scorer.score(ref, cand) for ref, cand in zip(references, candidates)]
        return scores
        """
        print("\nNote: ROUGE score calculation is a placeholder. Install and use 'rouge-score' library for actual metrics.")
        return {'rouge-1': 'N/A', 'rouge-2': 'N/A', 'rouge-L': 'N/A'}

    all_actuals, all_predictions = [], []
    for batch_source, batch_target in test_ds.take(1):
        batch_predictions = transformer_model.predict(batch_source)
        predicted_token_ids = tf.argmax(batch_predictions, axis=-1).numpy()
        for i in range(predicted_token_ids.shape[0]):
            input_text = tokens_to_text(batch_source['encode_inp'][i].numpy(), index_to_text)
            predicted_text = tokens_to_text(predicted_token_ids[i], index_to_label)
            actual_text = tokens_to_text(batch_target[i].numpy(), index_to_label)

            all_actuals.append(actual_text)
            all_predictions.append(predicted_text)

            print(f"Input Text: {input_text}")
            print(f"Predicted Label: {predicted_text}")
            print(f"Actual Label: {actual_text}")
            print("-" * 20)

    # Calculate ROUGE scores on the batch predictions
    # This is a placeholder call. Replace with real implementation.
    rouge_scores = calculate_rouge_scores(all_actuals, all_predictions)
    print("ROUGE Scores (on a single test batch):", rouge_scores)

except Exception as e:
    print(f"\nAn error occurred during training: {e}")
    print("Please check your data paths, NLTK downloads, and the error traceback for more details.")
# Out:
# --- Building Full Transformer Model ---
# Starting training for 200 epochs (with EarlyStopping up to 10 epochs patience).
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 78s/step - loss: 4.2733 - mask_accuracy: 0.1066
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 585s 85s/step - loss: 4.2816 - mask_accuracy: 0.1064 - val_loss: 3.4998 - val_mask_accuracy: 0.0521
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77s/step - loss: 3.1916 - mask_accuracy: 0.1063
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 506s 84s/step - loss: 3.1705 - mask_accuracy: 0.1125 - val_loss: 2.8612 - val_mask_accuracy: 0.0802
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77s/step - loss: 2.8629 - mask_accuracy: 0.1201
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 524s 87s/step - loss: 2.8617 - mask_accuracy: 0.1192 - val_loss: 2.6560 - val_mask_accuracy: 0.1984
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77s/step - loss: 2.7461 - mask_accuracy: 0.1492
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 506s 83s/step - loss: 2.7452 - mask_accuracy: 0.1511 - val_loss: 2.6525 - val_mask_accuracy: 0.1984
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77s/step - loss: 2.7242 - mask_accuracy: 0.1800
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 582s 88s/step - loss: 2.7236 - mask_accuracy: 0.1790 - val_loss: 2.5944 - val_mask_accuracy: 0.1984
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77s/step - loss: 2.6920 - mask_accuracy: 0.1569
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 529s 88s/step - loss: 2.6916 - mask_accuracy: 0.1580 - val_loss: 2.5799 - val_mask_accuracy: 0.1984
# Epoch 7/200
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 2:55 88s/step - loss: 2.6702 - mask_accuracy: 0.1768

# %%
tf.keras.utils.plot_model(
    transformer_model,
    to_file="transformer_model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
    show_trainable=False,
)

# %%
print("\n--- Evaluating Model ---")
loss, accuracy = transformer_model.evaluate(test_ds)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# %%
print("\n--- Predicting and Comparing with Test Data ---")
label_vocab = loaded_label_vec.get_vocabulary()
index_to_label = {index: token for index, token in enumerate(label_vocab)}
text_vocab = loaded_text_vec.get_vocabulary()
index_to_text = {index: token for index, token in enumerate(text_vocab)}

def tokens_to_text(token_ids, vocab_map):
    tokens = [vocab_map.get(token_id, '[UNK]') for token_id in token_ids if token_id != 0]
    filtered_tokens = [token for token in tokens if token not in ['[start]', '[end]']]
    return ' '.join(filtered_tokens)

# Use the already trained model from the previous cell
if 'transformer_model' in locals():
    for batch_source, batch_target in test_ds.take(1): # Take a small batch for demonstration
        batch_predictions = transformer_model.predict(batch_source)
        predicted_token_ids = tf.argmax(batch_predictions, axis=-1).numpy()
        for i in range(predicted_token_ids.shape[0]):
            input_text = tokens_to_text(batch_source['encode_inp'][i].numpy(), index_to_text)
            predicted_text = tokens_to_text(predicted_token_ids[i], index_to_label)
            actual_text = tokens_to_text(batch_target[i].numpy(), index_to_label)
            print(f"Input Text: {input_text}")
            print(f"Predicted Label: {predicted_text}")
            print(f"Actual Label: {actual_text}")
            print("-" * 20)
else:
    print("Model 'transformer_model' not found. Please train the model first.")

# %%
print("\n--- Predicting and Comparing with Test Data ---")
label_vocab = loaded_label_vec.get_vocabulary()
index_to_label = {index: token for index, token in enumerate(label_vocab)}
text_vocab = loaded_text_vec.get_vocabulary()
index_to_text = {index: token for index, token in enumerate(text_vocab)}

def tokens_to_text(token_ids, vocab_map):
    tokens = [vocab_map.get(token_id, '[UNK]') for token_id in token_ids if token_id != 0]
    filtered_tokens = [token for token in tokens if token not in ['[start]', '[end]']]
    return ' '.join(filtered_tokens)

# Use the already trained model from the previous cell
if 'transformer_model' in locals():
    for batch_source, batch_target in test_ds.take(1): # Take a small batch for demonstration
        batch_predictions = transformer_model.predict(batch_source)
        predicted_token_ids = tf.argmax(batch_predictions, axis=-1).numpy()
        for i in range(predicted_token_ids.shape[0]):
            input_text = tokens_to_text(batch_source['encode_inp'][i].numpy(), index_to_text)
            predicted_text = tokens_to_text(predicted_token_ids[i], index_to_label)
            actual_text = tokens_to_text(batch_target[i].numpy(), index_to_label)
            print(f"Input Text: {input_text}")
            print(f"Predicted Label: {predicted_text}")
            print(f"Actual Label: {actual_text}")
            print("-" * 20)
else:
    print("Model 'transformer_model' not found. Please train the model first.")

# %% [markdown]
# # Predicting Entire Dataset

# %%
df_combined = pd.read_excel('combined_data.xlsx')

# %%
# --- Assuming the following functions and objects are defined in previous cells ---
# def normalize(text, label): ...
# loaded_text_vec = TextVectorization(...)
# loaded_label_vec = TextVectorization(...)
# transformer_model = tf.keras.Model(...)
# --------------------------------------------------------------------------------

# 1. Prepare the data for autoregressive generation
texts_to_predict = df_combined['combined'].tolist()
normalized_texts = [normalize(text, "")[0] for text in texts_to_predict]

# %%
def format_dataset_for_generation(text):
    text_vec = loaded_text_vec(text)
    return text_vec

predict_ds_gen = tf.data.Dataset.from_tensor_slices((normalized_texts)).batch(64)
predict_ds_gen = predict_ds_gen.map(format_dataset_for_generation)

# Get special token IDs from the vocabulary
label_vocab = loaded_label_vec.get_vocabulary()
start_token = loaded_label_vec('[start]')[0].numpy()
end_token = loaded_label_vec('[end]')[0].numpy()
max_seq_len = loaded_label_vec.get_config()['output_sequence_length']

# %%
def generate_labels_autoregressive(model, text_input, start_token, end_token, max_len, p=0.9):
    """
    Generates a sequence of labels autoregressively using Top-p (Nucleus) sampling.
    Pads the decoder input to max_len - 1 for compatibility with the model's expected input shape.
    """
    batch_size = tf.shape(text_input)[0]
    # Get the vocabulary size from the loaded_label_vec layer
    vocab_size = loaded_label_vec.vocabulary_size()
    # Get the padding token ID (assuming it's 0 due to mask_zero=True)
    padding_token = 0

    # Initialize the decoder input with the start token for each sequence in the batch
    decoder_input = tf.fill(dims=(batch_size, 1), value=start_token)

    # Loop to generate tokens one by one up to max_len
    for i in range(max_len): # Iterate up to max_len to generate sequences up to max_len tokens long
        # Pad the current decoder_input to the expected sequence length for the model
        current_seq_len = tf.shape(decoder_input)[1]
        padding_needed = max_len - 1 - current_seq_len # Model expects max_len - 1 input tokens
        if padding_needed < 0: # Should not happen with proper max_len
             padding_needed = 0
        padding_shape = [[0, 0], [0, padding_needed]]
        padded_decoder_input = tf.pad(decoder_input, padding_shape, "CONSTANT", constant_values=padding_token)

        # Pass the encoded text and the padded generated sequence to the model
        # Only pass the first max_len - 1 tokens of the padded input to match the model's expected shape
        predictions = model({'encode_inp': text_input, 'decode_inp': padded_decoder_input[:, :max_len-1]})


        # Get the logits for the next token (which corresponds to the last non-padded token position)
        # The index should be the position after the last generated token
        last_token_position = current_seq_len - 1
        last_token_logits = predictions[:, last_token_position, :]


        # Reshape logits to 2D for Top-p sampling
        logits_2d = tf.reshape(last_token_logits, [-1, vocab_size])

        # Apply Top-p (Nucleus) sampling
        sorted_logits = tf.sort(logits_2d, axis=-1, direction='DESCENDING')
        sorted_indices = tf.argsort(logits_2d, axis=-1, direction='DESCENDING')
        cumulative_probs = tf.cumsum(tf.nn.softmax(sorted_logits, axis=-1), axis=-1)

        # Create a mask to filter tokens based on cumulative probability p
        indices_to_remove = cumulative_probs > p
        # Ensure that the first token (most likely) is never removed
        indices_to_remove = tf.concat([
            tf.zeros([tf.shape(indices_to_remove)[0], 1], dtype=tf.bool),
            indices_to_remove[:, :-1]
        ], axis=-1)
        # Mask the logits
        masked_logits = tf.where(indices_to_remove, -1e9, sorted_logits)

        # Sample a single token from the filtered distribution
        sampled_indices_in_sorted_order = tf.random.categorical(masked_logits, num_samples=1)
        # Get the actual token IDs from the original vocabulary indices
        next_tokens = tf.gather(sorted_indices, sampled_indices_in_sorted_order, batch_dims=1)


        # Concatenate the new token to the generated sequence
        decoder_input = tf.concat([decoder_input, tf.cast(next_tokens, dtype=tf.int64)], axis=1)

        # Stop if all sequences in the batch have generated the end token
        # We check the newly generated token
        if tf.reduce_all(tf.equal(next_tokens, end_token)):
            break

    return decoder_input

# %%
all_predicted_token_ids = []
for batch_text_input in predict_ds_gen:
    batch_predictions = generate_labels_autoregressive(
        transformer_model,
        batch_text_input,
        start_token=start_token,
        end_token=end_token,
        max_len=max_seq_len,
        p=0.9
    )
    all_predicted_token_ids.extend(batch_predictions.numpy())

# 4. Convert predicted token IDs to human-readable labels
index_to_label = {index: token for index, token in enumerate(label_vocab)}
predicted_labels_human_readable = []
for token_ids in all_predicted_token_ids:
    tokens = [index_to_label.get(token_id, '[UNK]') for token_id in token_ids if token_id != 0]
    filtered_tokens = [token for token in tokens if token not in ['[start]', '[end]']]
    predicted_labels_human_readable.append(' '.join(filtered_tokens))

# 5. Create a new DataFrame and save it
output_df = pd.DataFrame({
    'Original Text': df_combined['combined'],
    'Predicted Label': predicted_labels_human_readable,
    'Actual Label': df_combined['Unnamed: 0']
})
output_df.to_excel('predictions_output_new.xlsx', index=False)

print("Prediction results saved to 'predictions_output_new.xlsx'")
print("First 10 human-readable predicted labels:")
for i, label in enumerate(predicted_labels_human_readable[:10]):
    print(f"Sample {i+1}: {label}")

# %%
# Assuming the list 'all_predicted_token_ids' is populated from your previous code.
# Also assuming 'df_combined' and 'loaded_label_vec' are available from earlier in your notebook.

# 1. Convert predicted token IDs to human-readable labels
# Retrieve the label vocabulary
label_vocab = loaded_label_vec.get_vocabulary()

# Create a mapping from token IDs to labels
index_to_label = {index: token for index, token in enumerate(label_vocab)}

# Function to convert token IDs to text
def tokens_to_text(token_ids, vocab_map):
    tokens = [vocab_map.get(token_id, '[UNK]') for token_id in token_ids if token_id != 0]
    filtered_tokens = [token for token in tokens if token not in ['[start]', '[end]']]
    return ' '.join(filtered_tokens)

predicted_labels_human_readable = []
for token_ids in all_predicted_token_ids:
    predicted_labels_human_readable.append(tokens_to_text(token_ids, index_to_label))

# 2. Create a new DataFrame with the original text, predicted labels, and actual labels
output_df = pd.DataFrame({
    'Original Text': df_combined['combined'],
    'Predicted Label': predicted_labels_human_readable,
    'Actual Label': df_combined['Unnamed: 0']
})

# 3. Save the DataFrame to a new Excel file
output_df.to_excel('predictions_output_final.xlsx', index=False)

print("Prediction results have been saved to 'predictions_output_final.xlsx'")
print("\nFirst 10 human-readable predicted labels:")
for i, label in enumerate(predicted_labels_human_readable[:10]):
    print(f"Sample {i+1}: {label}")

# %% [markdown]
# **Reasoning**:
# Create a new DataFrame with the original text, predicted labels, and actual labels, and save it to an Excel file.

# %% [markdown]
# # TESTING NEW SET OF PATENTS

# %%
df_new = pd.read_excel('New set of patents _Input.xlsx')

# %%
df_new.head()

# %%
# Remove the first four rows
df_new = df_new.iloc[4:]

# Remove the first two columns
df_new = df_new.iloc[:, 2:]

# Display the first few rows of the modified DataFrame to verify
display(df_new.head())

# %%
# Combine all columns into a single 'combined' column, similar to the original data
df_new['combined'] = df_new.astype(str).agg(' '.join, axis=1)

# Create a new DataFrame with only the 'combined' column
df_new_combined = df_new[['combined']].copy()

# Display the first few rows of the modified DataFrame to verify
display(df_new_combined.head())

# %%
# 1. Prepare the new data for autoregressive generation
texts_to_predict_new = df_new_combined['combined'].tolist()

# Assuming the normalize function is defined in a previous cell
normalized_texts_new = [normalize(text, "")[0] for text in texts_to_predict_new]

# 2. Format the new dataset for prediction
# Assuming format_dataset_for_generation is defined in a previous cell
predict_ds_new_gen = tf.data.Dataset.from_tensor_slices((normalized_texts_new)).batch(64)
predict_ds_new_gen = predict_ds_new_gen.map(format_dataset_for_generation)

# 3. Generate labels using the trained transformer model (autoregressive)
# Assuming generate_labels_autoregressive is defined and transformer_model,
# start_token, end_token, and max_seq_len are available from previous cells.

all_predicted_token_ids_new = []
for batch_text_input in predict_ds_new_gen:
    batch_predictions_new = generate_labels_autoregressive(
        transformer_model,
        batch_text_input,
        start_token=start_token,
        end_token=end_token,
        max_len=max_seq_len,
        p=0.9
    )
    all_predicted_token_ids_new.extend(batch_predictions_new.numpy())

# 4. Convert predicted token IDs to human-readable labels
# Assuming loaded_label_vec and index_to_label from previous cells
predicted_labels_human_readable_new = []
for token_ids in all_predicted_token_ids_new:
    # Assuming tokens_to_text function is defined in a previous cell
    predicted_labels_human_readable_new.append(tokens_to_text(token_ids, index_to_label))


# 5. Create a new DataFrame with the original text and predicted labels
output_df_new = pd.DataFrame({
    'Original Text (New Dataset)': texts_to_predict_new,
    'Predicted Label (New Dataset)': predicted_labels_human_readable_new
})

# 6. Display the first few predictions
print("First 10 human-readable predicted labels for the new dataset:")
for i, label in enumerate(predicted_labels_human_readable_new[:10]):
    print(f"Sample {i+1}: {label}")

# You can now save output_df_new to an Excel file if needed
# output_df_new.to_excel('new_predictions_output.xlsx', index=False)

# %% [markdown]
# # SUMMARIZATION

# %%
df2 = pd.read_excel('Manual Analysis_input.xlsx')
df2

# %%
# Remove the first 4 rows
df_modified = df2.iloc[4:].copy()

# Remove the first column (S.No)
df_modified = df_modified.iloc[:, 1:].copy()

print(df_modified.head())

# Export to Excel file
output_excel_path = 'df2_modified.xlsx'
df_modified.to_excel(output_excel_path, index=False)

print(f"Modified DataFrame saved to '{output_excel_path}'")

# %%
import pandas as pd
import re
import textwrap
from transformers import pipeline

def create_template_summary(publication_number, abstract, full_claims, summarizer_model):
    """
    Generates a structured summary for a patent, following a specific template.

    Args:
        publication_number (str): The patent's publication number.
        abstract (str): The abstract text of the patent.
        full_claims (str): The full claims text of the patent.
        summarizer_model: A Hugging Face summarization pipeline.

    Returns:
        str: The formatted summary string.
    """
    summary_parts = []

    # Use a transformer model for the main abstract-like summary
    try:
        main_summary_output = summarizer_model(
            abstract,
            min_length=30,
            max_length=80,
            do_sample=False
        )
        main_summary_text = main_summary_output[0]['summary_text']
    except Exception as e:
        main_summary_text = f"An error occurred during summarization: {e}. Unable to generate an abstract."

    # 1. Abstract summarizing the key focus and mechanisms
    summary_parts.append(f"### {publication_number}\n\nAbstract summarizing the key focus and mechanisms of the invention: {main_summary_text}")

    # 2. Important Features: Extract sections based on claims
    summary_parts.append("\nImportant Features:")

    independent_claims = []
    if isinstance(full_claims, str) and full_claims.strip():
        # A regex to find claims starting with a number followed by a period.
        claims_list = re.split(r'\n\s*\d+\.\s*', full_claims, flags=re.MULTILINE | re.DOTALL)
        # The first element is usually empty or pre-claim text
        claims_list = [claim.strip() for claim in claims_list if claim.strip()]

        independent_claims = [claim for claim in claims_list if not re.match(r'^\w+ according to claim', claim)]

    for i, claim in enumerate(independent_claims[:3]):
        claim_summary = ""
        # Use the transformer to summarize each independent claim, or fall back to the first sentence.
        try:
            snippet_summary_output = summarizer_model(claim, max_length=50, min_length=20, do_sample=False)
            claim_summary = snippet_summary_output[0]['summary_text']
        except Exception:
            claim_summary = claim.split('.')[0].strip() + '.'

        summary_parts.append(f"· Main feature or concept of Independent claim {i+1} – {claim_summary}")

    # 3. Benefits section (placeholder or simple keyword extraction)
    benefits_list = []
    abstract_lower = abstract.lower()
    if "improves" in abstract_lower or "efficiency" in abstract_lower:
        benefits_list.append("The invention provides improvements in efficiency or functionality.")
    if "biodegradable" in abstract_lower or "recyclable" in abstract_lower:
        benefits_list.append("The invention offers environmental benefits such as biodegradability or recyclability.")

    if benefits_list:
        summary_parts.append("\nBenefits include:")
        for benefit in benefits_list:
            summary_parts.append(f"- {benefit}")
    else:
        summary_parts.append("\nBenefits include: The invention addresses a problem in the prior art, leading to specific benefits for the user or manufacturing process.")

    full_summary = "\n".join(summary_parts)

    # Final cleanup to enforce word count and remove unwanted words
    words = full_summary.split()
    if len(words) > 150:
        full_summary = " ".join(words[:150]) + "..."

    unwanted_phrases = ['novel', 'innovative', 'invention relates to', 'the present invention', 'provided is', 'disclosed is', 'characterize']
    for phrase in unwanted_phrases:
        full_summary = re.sub(r'\b' + re.escape(phrase) + r'\b', '', full_summary, flags=re.IGNORECASE)

    full_summary = re.sub(r'\s+', ' ', full_summary).strip()
    return full_summary

def run_patent_summarization_pipeline(file_path):
    """
    A complete pipeline to generate structured summaries for patents from an Excel file.
    """
    try:
        # Load the file, assuming a header is present. The script will dynamically find it.
        # This is more robust than relying on a hardcoded row index.
        patent_data = pd.read_csv(file_path, header=None, skiprows=3)
        # The actual header seems to be the first row of this new dataframe, so let's set it.
        patent_data.columns = patent_data.iloc[0]
        patent_data = patent_data.iloc[1:].copy()

        print("Data loaded successfully.")
    except Exception as e:
        print(f"Error loading data from '{file_path}': {e}")
        return

    # Initialize the summarization model
    try:
        summarizer = pipeline("summarization", model="sshleifer/distilbart-cnn-12-6", framework="pt")
        print("Summarization model loaded successfully.")
    except Exception as e:
        print(f"Error loading summarization model: {e}")
        return

    generated_summaries = []

    print("\nStarting summarization processing...")
    for index, row in patent_data.iterrows():
        publication_number = str(row['Publication Number']) if 'Publication Number' in row.index and not pd.isna(row['Publication Number']) else f"Index {index}"
        abstract = str(row['Abstract']) if 'Abstract' in row.index and not pd.isna(row['Abstract']) else ''
        full_claims = str(row['Full Claims']) if 'Full Claims' in row.index and not pd.isna(row['Full Claims']) else ''

        # Check for meaningful content to prevent model from generating junk.
        input_text_for_summary = f"{abstract} {full_claims}"
        if not input_text_for_summary.strip() or input_text_for_summary.strip().lower() == 'nan':
            print(f"Skipping patent {publication_number}: No valid abstract or claims found.")
            summary_text = "No content available for summarization."
        else:
            # Generate a summary based on the template.
            summary_text = create_template_summary(publication_number, abstract, full_claims, summarizer)
            print(f"Processed patent {publication_number}")
            print("\nGenerated Summary:\n" + "="*20)
            print(summary_text)
            print("="*20 + "\n")

        generated_summaries.append(summary_text)

    # Add the results to the DataFrame.
    patent_data['Generated_Summary'] = generated_summaries

    # Save the updated DataFrame to a new Excel file.
    output_file_path = "summarized_patents.xlsx"
    patent_data.to_excel(output_file_path, index=False)
    print(f"\nPipeline complete! Results saved to '{output_file_path}'.")

# Run the pipeline with your file path.
file_path = 'Manual Analysis_input.xlsx - Analysed Patents.csv'
run_patent_summarization_pipeline(file_path)

# %%
# After running the pipeline and adding the 'Generated_Summary' column to patent_data
# you can print the summaries like this:
print("\nGenerated Summaries:")
if patent_data is not None:
  print(patent_data['Generated_Summary'].tolist())
else:
  print("No patent data was processed.")
